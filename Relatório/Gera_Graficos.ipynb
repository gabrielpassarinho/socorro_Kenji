# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plota_reta(x, y, nome):
    coef = np.polyfit(x,y,1) # x*coef[0] + coef[1] = y

    x_linha = x
    y_linha = x*coef[0]+np.array([coef[1] for i in range(len(x))])
    fig, ax = plt.subplots()
    ax.set(xlabel='log do tamanho da entrada', ylabel='log do tempo de ordenacao', 
           title='Tempo de ordenacao de um vetor random no metodo '+nome)

    fig = plt.figure(figsize=(10, 10))
    ax.scatter(x, y)
    ax.plot(x_linha, y_linha)
    ax.annotate('slope ='+str(coef[0].round(2)), (5, -9))

    plt.show()
    
    return fig

# %%
# entrada random

# HS 
y = np.log(np.array([ 0.000001, 0.000005, 0.000060, 0.000449, 0.004972]))
x = np.log(np.array([ 10, 100, 1000, 10000, 100000]))

plota_reta(x, y, 'Heapsort')

# BS
y = np.log(np.array([0.000013, 0.000820, 0.053089, 5.987348])) # exclui o primeiro tempo, pois ele valia 0
x = np.log(np.array([ 100, 1000, 10000, 100000]))

plota_reta(x, y, 'Bubblesort')

# QS
y = np.log(np.array([0.000003, 0.000030, 0.000226, 0.002718])) # exclui o primeiro tempo, pois ele valia 0
x = np.log(np.array([ 100, 1000, 10000, 100000]))

plota_reta(x, y, 'Quicksort')

# RS
y = np.log(np.array([ 0.000001, 0.000004, 0.000039, 0.000317, 0.003900]))
x = np.log(np.array([ 10, 100, 1000, 10000, 100000]))

plota_reta(x, y, 'Radixsort')
